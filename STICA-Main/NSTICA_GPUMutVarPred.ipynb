# %%
#Analysis

import numpy as np
COND_SET = [(50, 10, 2), (50, 20, 2), (50, 32, 2), (50, 64, 2), (50, 100, 2), (100, 10, 2), (100, 20, 2), (100, 32, 2), (100, 64, 2), (100, 100, 2), (200, 10, 2), (200, 20, 2), (200, 32, 2), (200, 64, 2), (200, 100, 2), (500, 10, 2), (500, 20, 2), (500, 32, 2), (500, 64, 2), (500, 100, 2), (50, 10, 3), (50, 20, 3), (50, 32, 3), (50, 64, 3), (100, 10, 3), (100, 20, 3), (100, 32, 3), (200, 10, 3), (200, 20, 3), (200, 32, 3), (500, 10, 3), (500, 20, 3), (50, 10, 4), (50, 20, 4), (50, 32, 4), (100, 10, 4), (100, 20, 4), (200, 10, 4), (500, 10, 4), (50, 10, 5), (50, 20, 5), (100, 10, 5), (200, 10, 5), (50, 10, 6)]
COND_SET_1 = [(50, 10, 3), (50, 20, 3), (50, 32, 3), (50, 64, 3), (100, 10, 3), (100, 20, 3), (100, 32, 3), (100, 64, 3), (200, 10, 3), (200, 20, 3), (200, 32, 3), (200, 64, 3), (500, 10, 3), (500, 20, 3), (500, 32, 3)]
def comp(a):
    it = a[0]
    sz = a[1]
    st = a[2]
    if (st == 2): 
        st = 18
    elif (st == 3): 
        st = 135
    elif (st == 4): 
        st = 660
    elif (st == 5): 
        st = 2475
    elif (st == 6): 
        st = 7722
    if (st*it*(sz**2) > 50000000):
        print(f"({st}, {it}, {sz}) is problematic")
    return st*it*(sz**2)
for i in range (len(COND_SET)):
    COND_SET[i] = comp(COND_SET[i])
for i in range (len(COND_SET_1)):
    COND_SET_1[i] = comp(COND_SET_1[i])
print(COND_SET)
COND_SET = np.array(COND_SET)
COND_SET_1 = np.array(COND_SET_1)
print(np.sum(COND_SET))
print(np.sum(COND_SET[0:20]))
print(np.sum(COND_SET[20:35]))
print(np.sum(COND_SET[35:44]))
print(np.sum(COND_SET[44:49]))
print(np.sum(COND_SET[49:51]))
a = (np.sum(COND_SET_1)/404*60)
print(np.sum(COND_SET[0:20])/a)
print(np.sum(COND_SET[20:35])/a)
print(np.sum(COND_SET[35:44])/a)
print(np.sum(COND_SET[44:49])/a)
print(np.sum(COND_SET[49:51])/a)
print(np.sum(COND_SET)/a)
# Out:
# (18, 500, 100) is problematic
# (135, 100, 64) is problematic
# (135, 200, 64) is problematic
# (135, 500, 32) is problematic
# [90000, 360000, 921600, 3686400, 9000000, 180000, 720000, 1843200, 7372800, 18000000, 360000, 1440000, 3686400, 14745600, 36000000, 900000, 3600000, 9216000, 36864000, 90000000, 675000, 2700000, 6912000, 27648000, 1350000, 5400000, 13824000, 2700000, 10800000, 27648000, 6750000, 27000000, 3300000, 13200000, 33792000, 6600000, 26400000, 13200000, 33000000, 12375000, 49500000, 24750000, 49500000, 38610000]
# 676620000
# 238986000
# 183699000
# 253935000
# 0
# 0
# 4.367825414274663
# 3.3573730711290257
# 4.641040674239648
# 0.0
# 0.0
# 12.366239159643337
